# %%
marks=[80,40,57,90,23]
print(marks[0])
# Out:
# 80

# %%
list=[24,56,78,40]
list.append(90)
print(list)
# Out:
# [24, 56, 78, 40, 90]

# %%
tuple=(11,33,44,67,89,34)
print (tuple[3])
# Out:
# 67

# %%
set={10,20,30,10,34,56}
print(set)
# Out:
# {34, 20, 56, 10, 30}

# %%
student={"name":"manu","age":23,"marks":98}
print(student["name"])
# Out:
# manu

# %%
string="welcome"
print(string[3])
print(string[-3])
# Out:
# c
# o
