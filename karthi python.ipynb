# %%
print("hello")
# Out:
# hello

# %%
a=int(input("enter the first num"))
b=int(input("enter the second num"))
c=a+b
print(c)
# Out:
# enter the first num56
# enter the second num34
# 90

# %%
a=int(input("enter the first num"))
b=int(input("enter the second num"))
c=a/b
print(c)
# Out:
# enter the first num22
# enter the second num2
# 11.0

# %%
a=int(input("enter the first num"))
b=int(input("enter the second num"))
c=a%b
print(c)
# Out:
# enter the first num24
# enter the second num4
# 0

# %%
a=int(input("enter the first num"))
b=int(input("enter the second num"))
c=int(input("enter the third num"))
d=a+b+c
avg=d/3
print(avg)
# Out:
# enter the first num2
# enter the second num4
# enter the third num6
# 4.0

# %%
r=int(input("enter the radius of the circle:"))
pi=3.14
area=pi*r*r
print(area)
# Out:
# enter the radius of the circle:4
# 50.24

# %%
c=float(input("enter the celcius:"))
F=c*9/5+32
print(F)
# Out:
# enter the celcius:38
# 100.4

# %%
f=float(input("enter the fahrenheit:"))
c=(f-32)*5/9
print(c)
# Out:
# enter the fahrenheit:100.4
# 38.0

# %%
num = int(input("Enter a number: "))

if num >= 0:
    print("positive")
else:
    print("negative")
# Out:
# Enter a number: 3
# positive

# %%
a = int(input("Enter the first num: "))
b = int(input("Enter the second num: "))

if a > b:
    print("a > b")
elif b > a:
    print("b > a")
else:
    print("a == b")
# Out:
# Enter the first num: 2
# Enter the second num: 5
# b > a

# %%
num = int(input("Enter a number: "))

if num % 2== 0:
    print("even")
else:
    print("odd")
# Out:
# Enter a number: 67
# odd

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
if num1 == num2:
    print("both num are equal")
else:
    print("both num are not equal")
# Out:
# Enter first number: 34
# Enter second number: 56
# both num are not equal

# %%
num = int(input("Enter a number: "))

if num > 100:
    print("Entered num is greater than 100")
elif num < 100:
    print("Entered num is not greater than 100")
else:
    print("Entered num is 100")
# Out:
# Enter a number: 103
# Entered num is greater than 100

# %%
age = int(input("Enter your age: "))

if age > 18:
    print("eligible for vote")
else:
    print("not eligible for vote")
# Out:
# Enter a number: 17
# not eligible for vote

# %%
mark = int(input("Enter your mark: "))

if mark >= 90:
    print("A grade")
elif mark >= 75:
    print("B grade")
elif mark >= 50:
    print("C grade")   
else:
    print("you failed")
# Out:
# Enter your mark: 67
# C grade

# %%
num = int(input("Enter a number: "))

if num > 0:
    print("positive")
elif num < 0:
    print("negative")
else:
    print("given num is zero")
# Out:
# Enter a number: 0
# given num is zero

# %%
a = int(input("Enter the first num: "))
b = int(input("Enter the second num: "))
c = int(input("Enter the third num: "))

if a > b and b > c:
    print("a is the greatest")
elif b > c and c > a:
    print("b is the greatest")
else:
    print("c is the greatest")
# Out:
# Enter the first num: 34
# Enter the second num: 67
# Enter the third num: 89
# c is the greatest

# %%
age = int(input("Enter your age: "))
if age < 13:
    print("you are a child")
elif age < 18:
    print("you are a teenager")
else:
    print("you are an adult")
# Out:
# Enter your age: 17
# you are a teenager

# %%
num = int(input("Enter a number between 1-7: "))

if num == 1:
    print("monday")
elif num == 2:
    print("tuesday")
elif num == 3:
    print("wednesday")
elif num == 4:
    print("thursday")
elif num == 5:
    print("friday")
elif num == 6:
    print("saturday")
elif num == 7:
    print("sunday")
else:
    print("entered num is not valid")
# Out:
# Enter a number between 1-7: 5
# friday

# %%
num = int(input("Enter a number between 1-12: "))

if num == 1:
    print("january")
elif num == 2:
    print("february")
elif num == 3:
    print("march")
elif num == 4:
    print("april")
elif num == 5:
    print("may")
elif num == 6:
    print("june")
elif num == 7:
    print("july")
elif num == 8:
    print("august")
elif num == 9:
    print("september")
elif num == 10:
    print("october")
elif num == 11:
    print("november")
elif num == 12:
    print("december")    
else:
    print("entered num is not valid")
# Out:
# Enter a number between 1-12: 6
# june
