# %%
print("hello")
# Out:
# hello

# %%
a=int(input("enter the first num"))
b=int(input("enter the second num"))
c=a+b
print(c)
# Out:
# enter the first num56
# enter the second num34
# 90

# %%
a=int(input("enter the first num"))
b=int(input("enter the second num"))
c=a/b
print(c)
# Out:
# enter the first num22
# enter the second num2
# 11.0

# %%
a=int(input("enter the first num"))
b=int(input("enter the second num"))
c=a%b
print(c)
# Out:
# enter the first num24
# enter the second num4
# 0

# %%
a=int(input("enter the first num"))
b=int(input("enter the second num"))
c=int(input("enter the third num"))
d=a+b+c
avg=d/3
print(avg)
# Out:
# enter the first num2
# enter the second num4
# enter the third num6
# 4.0

# %%
r=int(input("enter the radius of the circle:"))
pi=3.14
area=pi*r*r
print(area)
# Out:
# enter the radius of the circle:4
# 50.24

# %%
c=float(input("enter the celcius:"))
F=c*9/5+32
print(F)
# Out:
# enter the celcius:38
# 100.4

# %%
f=float(input("enter the fahrenheit:"))
c=(f-32)*5/9
print(c)
# Out:
# enter the fahrenheit:100.4
# 38.0

# %%
a=int(input("enter the first num"))
b=int(input("enter the second num"))
if a > b:
print("a > b")
elif
print("b > a")
else:
    print("a == b")
# Out:
#   File "C:\Users\AWH10~1\AppData\Local\Temp/ipykernel_9448/3310921497.py", line 4
#     print("a > b")
#     ^
# IndentationError: expected an indented block

# %%
a=int(input("enter the first num"))
b=int(input("enter the second num"))
if a>b:
print("a>b")
elif
print("b>a")
else:
    print("a==b")
# Out:
#   File "C:\Users\AWH10~1\AppData\Local\Temp/ipykernel_9448/3744358249.py", line 4
#     print("a>b")
#     ^
# IndentationError: expected an indented block
